// %%
//import $ivy.`com.amazonaws:aws-java-sdk:1.11.22`

import $ivy.`com.github.seratch::awscala:0.5.+`

import awscala._, ec2._
import scala.concurrent._
import scala.concurrent.ExecutionContext.Implicits.global
// Out:
// ...
// Downloaded https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk/1.11.22/aws-java-sdk-1.11.22.pom.sha1
// Downloaded https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk/1.11.22/aws-java-sdk-1.11.22.pom
// ...
// Downloaded https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-pom/1.11.22/aws-java-sdk-pom-1.11.22.pom
// Downloaded https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-pom/1.11.22/aws-java-sdk-pom-1.11.22.pom.sha1
// ...
// Downloaded https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-opsworks/1.11.22/aws-java-sdk-opsworks-1.11.22.pom.sha1
// ...
// Downloaded https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-lambda/1.11.22/aws-java-sdk-lambda-1.11.22.pom
// ...
// Downloaded https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-efs/1.11.22/aws-java-sdk-efs-1.11.22.pom
// ...
// Downloaded https://repo1.maven.org/maven2/com/amazonaws/aws-java-sdk-efs/1.11.22/aws-java-sdk-efs-1.11.22.pom.sha1
// ...

// %%
val region = Region.US_EAST_1
val ami = "ami-10f53a06"
val ec2 = EC2.at(region)
val key = ec2.keyPairs.filter(_.getKeyName=="atomic")(0)
//val inst = ec2.instances
// Out:
// region: Region = us-east-1
// ami: String = "ami-10f53a06"
// ec2: EC2 = awscala.ec2.EC2Client@2c6c7a1e
// key: KeyPair = {KeyName: atomic,KeyFingerprint: 29:09:1c:f2:5b:40:8f:a8:7e:db:3a:79:f3:c9:79:cb:6e:8a:91:0b,}

// %%
ec2.runInstances _
// Out:
// res22: com.amazonaws.services.ec2.model.RunInstancesRequest => com.amazonaws.services.ec2.model.RunInstancesResult = <function1>
